# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
x = 10

# %%
type(x)
# Out:
# int

# %%
a =5
b= 7
a+b
# Out:
# 12

# %%
a-b
# Out:
# -2

# %%
a*b
# Out:
# 35

# %%
b/a
# Out:
# 1.4

# %%
b=2.56

# %%
type(b)
# Out:
# float

# %%
d="aarushi"

# %%
type(d)
# Out:
# str

# %%
n = True

# %%
type(n)
# Out:
# bool

# %%
False/True
# Out:
# 0.0

# %%
True*True
# Out:
# 1
