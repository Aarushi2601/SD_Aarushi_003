# %%
x= 25

# %%
y = str(x)

# %%
print(y)
# Out:
# 25

# %%
x = (1,2,3)

# %%
y = list(x)

# %%
print(y)
# Out:
# [1, 2, 3]

# %%
x =[1,2,3]

# %%
y = tuple(x)

# %%
print(y)
# Out:
# (1, 2, 3)

# %%
x = [1,2,3]

# %%
y = set(x)

# %%
print(y)
# Out:
# {1, 2, 3}
