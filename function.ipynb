# %%
l = [1,2,3,4,5,45,5]
l1 =[]
for i in l :
  l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 25, 2025, 25]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 25, 2025, 25]

# %%
[i for i in l if i % 2 == 0]
# Out:
# [2, 4]

# %%
l1 = ["sudha" ,"skills" ,"kumar" ,"data science"]

# %%
[i.upper() for i in l1]
# Out:
# ['SUDHA', 'SKILLS', 'KUMAR', 'DATA SCIENCE']

# %%
list(i**2 for i in l)
# Out:
# [1, 4, 9, 16, 25, 2025, 25]

# %%
d = {"key1" :1 ,"key2" :2 ,"key3" :3 ,"key4" :4}

# %%
{k:v**2 for k ,v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k :v for k , v in d.items() if v>1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}

# %%
def test():
  pass

# %%
def test1 ():
  print("this is my first function")

# %%
test1()
# Out:
# this is my first function

# %%
test1() + "aarushi"
# Out:
# this is my first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_870/4027200642.py in <cell line: 0>()
# ----> 1 test1() + "aarushi"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my very first return"

# %%
 test2()
# Out:
# 'this is my very first return'

# %%
test2() + "sudh"
# Out:
# 'this is my very first returnsudh'

# %%
def test3():
  return"sudh" ,23,34,[1,2,3,4]

# %%
test3()
# Out:
# ('sudh', 23, 34, [1, 2, 3, 4])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'sudh'

# %%
def add():
  a = 5+6/7
  return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
   d = a+b/c
   return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
  return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("sudh", "kumar")
# Out:
# 'sudhkumar'

# %%
def test11(*args):
  return args

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3)

# %%
def test11(*kwargs):
  return kwargs + (1,2,3,4)

# %%
test11(1,2,3,"sudh","kumar",[1,2,3,4,4],1,2,3,4)
# Out:
# (1, 2, 3, 'sudh', 'kumar', [1, 2, 3, 4, 4], 1, 2, 3, 4, 1, 2, 3, 4)

# %%
def test12(*sudh):
  return sudh

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*args , a):
  return args , a

# %%
test13(1,2,3,4, a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a=23,b=1):
  return a,b,c,d

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):
  return kwargs

# %%
def test15(**kwargs):
  return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def calc(a,b,p):
  if(p == 1):
    print(a-b)
  elif(p == " "):
    print (a-b)
  elif(p == "*"):
    print(a*b)
  elif(p == "/"):
    print( a/b)
  return "done"
n1=int(input("enter num1"))
n2=int(input("enter num2"))
op=(input("enter opt"))
calc(n1,n2,op)
# Out:
# enter num12
# enter num24
# enter opt*
# 8
# 'done'

# %%
def deposit():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be deposited: "))
    customer["Amount"] = customer["Amount"] + money
def withdrawal():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be withdrawn: "))
    if customer["Amount"] < money:
      print("Not enough balance")
      return customer['Amount']
    else:
      customer["Amount"] = customer["Amount"] - money
      return customer["Amount"]
def amount():
  print(customer["Amount"])

def pin_change():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    npin = int(input("Enter new PIN: "))
    n2pin = int(input("Confirm PIN: "))
    if npin != n2pin:
      print("Not same")
    else:
      print("PIN changed succesfully")

customer = {"Card number" : 1234 , "PIN" : 789 , "Amount" : 4500 }
cnum = int(input("Enter Card number: "))
if cnum != customer["Card number"]:
  print("Invalid Card Number")
else:
  p = 1
  while p==1:
    service = int(input("Services :\n 1-DEPOSIT \n 2-WITHDRAWAL \n 3-PIN CHANGE \n 4-AMOUNT CHECK \n 5-EXIT \n Enter Service: "))
    if service == 1:
      deposit()
    elif service == 2:
      print("new amount :" ,withdrawal())
    elif service == 3:
      pin_change()
    elif service == 4:
      amount()
    elif service == 5:
      p=0
      print("THANKS FOR USING SERVICES...")
      break
    else:
      print("Invalid choice")
    inp = input("more services?(Y/N): ")
    if inp == 'N' or inp == 'n':
      p = 0
# Out:
# Enter Card number: 1234
# Services :
#  1-DEPOSIT
#  2-WITHDRAWAL
#  3-PIN CHANGE
#  4-AMOUNT CHECK
#  5-EXIT
#  Enter Service: 2
# Enter PIN: 4567
# Invalid PIN
# new amount : None
# more services?(Y/N): yes
# Services :
#  1-DEPOSIT
#  2-WITHDRAWAL
#  3-PIN CHANGE
#  4-AMOUNT CHECK
#  5-EXIT
#  Enter Service: 2
# Enter PIN: 1234
# Invalid PIN
# new amount : None
# more services?(Y/N): y
# Services :
#  1-DEPOSIT
#  2-WITHDRAWAL
#  3-PIN CHANGE
#  4-AMOUNT CHECK
#  5-EXIT
#  Enter Service: 2
# Enter PIN: 789
# Enter amount to be withdrawn: 200
# new amount : 4300
# more services?(Y/N): n
