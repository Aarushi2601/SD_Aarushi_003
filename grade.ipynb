# %%
l = [1,345,45,"sudh",True, 5+7j,345.56]

# %%
l[5].real
# Out:
# 5.0

# %%
l[-1:-5:-2]
# Out:
# [345.56, True]

# %%
l[-1]
# Out:
# 345.56

# %%
l[::-1]
# Out:
# [345.56, (5+7j), True, 'sudh', 45, 345, 1]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56]

# %%
s="aarushi"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_669/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['a', 'a', 'r', 'u', 's', 'h', 'i', 1, 345, 45, 'sudh', True, (5+7j), 345.56]

# %%
l1 = [3,4,5]

# %%
l +l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56, 3, 4, 5]

# %%
l1 * 3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
len(l)
# Out:
# 7

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56]

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.56, 'aarushi']

# %%
l.extend(4")
# Out:
#   File "/tmp/ipykernel_669/2909487322.py", line 1
#     l.extend(4")
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.56,
#  'aarushi',
#  's',
#  'u',
#  'd',
#  'h',
#  '4',
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.56,
#  'aarushi',
#  's',
#  'u',
#  'd',
#  'h',
#  '4',
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5]

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], 4, 5]

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], 4, 45, 5]

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4, 45, 5]

# %%
l1.pop()
# Out:
# 5

# %%
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 3, 'sudh', 4, 45]

# %%
l1.remove(3)

# %%
l1
# Out:
# [45, 'sudh', 4, 45]

# %%
l1.remove(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_669/2189347925.py in <cell line: 0>()
# ----> 1 l1.remove(234)
#
# ValueError: list.remove(x): x not in list

# %%
l1.append(4)

# %%
l1
# Out:
# [45, 'sudh', 4, 45, 4]

# %%
l1.remove(4)

# %%
l1
# Out:
# [45, 'sudh', 45, 4]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_669/2406146923.py in <cell line: 0>()
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2 = [ 45, 33 , 90 ,0,3,4,5,6,7,8,9]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 33, 45, 90]

# %%
l4 = ["sudh" ,"rohit" , "data science"]

# %%
l4.count("sudh")
# Out:
# 1

# %%
s = "sudh"

# %%
l5 = [23,56,32,45]

# %%
l5[0] = 30

# %%
l5
# Out:
# [30, 56, 32, 45]

# %%
s
# Out:
# 'sudh'

# %%
s.replace('s','a')
# Out:
# 'audh'

# %%
s
# Out:
# 'sudh'

# %%
t=(2,3,4,5,"sudh",45.56,False,45+457j,[3,4,5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5])

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3 = {324 ,456,"sudh" ,45+45j ,34.465 ,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'sudh'}

# %%
s4 = {2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
l6=[2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"]

# %%
s5={234,45,23,12,567,45,2,789,234,"abc",456,342,23}

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
 s5.remove(2)

# %%
s5
# Out:
# {12, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={'key' : "sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2 = {'name' : "sudhanshu" , "email" : "ss@gmail.com" , "number" : 334534}

# %%
d2
# Out:
# {'name': 'sudhanshu', 'email': 'ss@gmail.com', 'number': 334534}

# %%
 d3={234 : "sudh" , '_wer' : "kumar" , True : 24234}

# %%
d3
# Out:
# {234: 'sudh', '_wer': 'kumar', True: 24234}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 24234

# %%
d3[1]
# Out:
# 24234

# %%
d4 = {'name':"sudh" , 'mail_id' : "ss@gmail.com" , "name":"sudhanshu"}

# %%
d4['name']
# Out:
# 'sudhanshu'

# %%
marks = int(input("enter your marks"))
if marks >= 80:
  print("you will be a part of A0 batch")
elif marks >= 60 and marks< 80:
    print("you will be a part of A1 batch")
elif marks >= 40 and marks < 60 :
    print("you will be a part of A2 batch ")
else :
    print("you will be a part of A3 batch ")
# Out:
# enter your marks90
# you will be a part of A0 batch

# %%
name = str(input("enter your name"))
course = str(input("enter your course"))
branch = str(input("enter your branch"))
rollnumber = int(input("enter your roll number"))
marks = int(input("enter your marks"))
if marks >= 80:
  print("you will be a part of A0 batch")
elif marks >= 60 and marks< 80:
    print("you will be a part of A1 batch")
elif marks >= 40 and marks < 60 :
    print("you will be a part of A2 batch ")
else :
    print("you will be a part of A3 batch ")
# Out:
# enter your nameAarushi
# enter your course btech
# enter your branchcse
# enter your roll number03
# enter your marks 90
# you will be a part of A0 batch

# %%
marks = int(input("enter your marks"))
if marks >= 80:
  print("grade A")
elif marks >= 60 and marks< 80:
    print("grade B")
elif marks >= 40 and marks < 60 :
    print("Grade C ")
else :
    print("Grade D ")
# Out:
# enter your marks78
# grade B
