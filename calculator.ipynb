# %%
def calc(a,b,p):
  if(p == 1):
    print(a-b)
  elif(p == " "):
    print (a-b)
  elif(p == "*"):
    print(a*b)
  elif(p == "/"):
    print( a/b)
  return "done"
n1=int(input("enter num1"))
n2=int(input("enter num2"))
op=(input("enter opt"))
calc(n1,n2,op)
# Out:
# enter num17
# enter num26
# enter opt/
# 1.1666666666666667
# 'done'
